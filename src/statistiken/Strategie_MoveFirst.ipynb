# %%
from src.codeGameSimulation.GameUr import GameUr, Player, Dice, GameSettings
import gameBoardDisplay as gbd

from fractions import Fraction

import locale

import numpy as np

from helpers import colorboxplot, makeVlines, zeichneErrechnetenWert, drawGame, colors
from src.codeGameSimulation.store2db import getDataFromDB, getGameFromDB, getGSFromDB, getHistoryFromDB

# %config InlineBackend.figure_formats = ['svg']
import matplotlib.pyplot as plt
import matplotlib.style as mplstyle
import matplotlib.ticker as mt

locale.setlocale(locale.LC_NUMERIC, "german")

mplstyle.use("fast")
mplstyle.use("default")
# mpl.rcParams['figure.figsize'] = [20, 10]
import sqlite3

# %%
db_dir = "D:/Uni/BA/data/"
db_filename = "gameHistories_strategy_move_first"
prefix_graphics = "Zufall gegen Move First: "
graphic_dir = "movefirst"

# %%
ids,roundCounts, stepCounts, winners, settingsIDs = getDataFromDB(db_dir, db_filename)
gs_unordered = getGSFromDB(db_dir,db_filename)
print([len(id) for id in ids])
# Out:
# db load finished after 0:00:04.858097
# sort finished after 0:00:00.072016
# groupby finished after 0:00:00.083019
# sort finished after 0:00:00.305069
# split finished after 0:00:02.896654
# settings loaded
# [1000000]

# %%
labels_unordered = [" vs ".join([p.getStrategy().getName(
) for p in gs_.getPlayers()]) for gs_ in gs_unordered]
labels = [labels_unordered[i] for i in settingsIDs]
gameSettings = [gs_unordered[i] for i in settingsIDs]
labels
# Out:
# ['random vs MoveFirst']

# %%
rc = roundCounts[0]
figRounds7s, ax = plt.subplot_mosaic([["Boxplots Runden"]], figsize=[
    10, 2.5], layout="constrained")
# ax2 = plt.twinx(ax["Boxplots Runden"])
# makeHistogram(ax2,[rc],[""],colors[0],fill=False)
# ax2.set_ylabel("Wahrschenlichkeit")
zeichneErrechnetenWert(ax["Boxplots Runden"], "r",7)

colorboxplot([rc], ax["Boxplots Runden"], [""], [colors[0]])
ax["Boxplots Runden"].set_title(
    prefix_graphics+"Spiellänge in Runden für einen Stein [{0:n} Spiele]".format(len(rc), grouping=True))
ax["Boxplots Runden"].set_xlabel('empirisch bestimmte Spiellänge in Runden')
# Out:
# 7
# Text(0.5, 0, 'empirisch bestimmte Spiellänge in Runden')

# %%
rc = roundCounts[0]
roundInfo={"⌀": np.mean(rc), "min": np.min(rc), "max": np.max(rc),
 "p50": np.percentile(rc, 50),
 "p25": np.percentile(rc, 25),
 "p75": np.percentile(rc, 75),
 "p1": np.percentile(rc, 1),
 "p99": np.percentile(rc, 99),
 "min_count": rc.count(np.min(rc)),
 "max_count": rc.count(np.max(rc)),
 }
roundInfo
# Out:
# {'⌀': 52.6956,
#  'min': 29,
#  'max': 99,
#  'p50': 52.0,
#  'p25': 47.0,
#  'p75': 57.0,
#  'p1': 38.0,
#  'p99': 72.0,
#  'min_count': 3,
#  'max_count': 1}

# %% [markdown]
# ### Schritte

# %%
sc = stepCounts[0]
figSteps7s, ax = plt.subplot_mosaic([["Boxplots Schritte"]], figsize=[
    20, 2.5], layout="constrained")
zeichneErrechnetenWert(ax["Boxplots Schritte"], "s", 7)
colorboxplot([sc], ax["Boxplots Schritte"], [""], [colors[0]])
ax["Boxplots Schritte"].set_title(
    prefix_graphics+"Spiellänge in Schritten für sieben Steine [{0:n} Spiele]".format(len(sc), grouping=True))
ax["Boxplots Schritte"].set_xlim((60, 300))
for txt in ax["Boxplots Schritte"].texts:
    if txt.get_position()[0] > 300:
        print(txt.get_text())
        txt.set_text(txt.get_text()+"→")
        txt.set_x(300)
# Out:
# 7

# %% [markdown]
# ## typischer Spielverlauf

# %%
gameIDAvg = rc.index(int(np.round(roundInfo["⌀"])))

print("ID für Spiel mit durchschnittlicher Länge:", ids[0][gameIDAvg])
gameAvg = getGameFromDB(ids[0][gameIDAvg], db_dir, db_filename)
print("Daten geladen")
figMovement = drawGame(gameAvg, gameSettings[0], figsize=[18, 9], prefix_graphics=prefix_graphics)
# Out:
# ID für Spiel mit durchschnittlicher Länge: 7
# Daten geladen

# %% [markdown]
# ### Auswertung geworfen worden und verlorene Distanz

# %%
throwCount = [0,0]
throwDistance = [0, 0]
for p_i,p in enumerate(gameAvg["stones"]):
    for s in gameAvg["stones"][p]:
        tc =sum([x < gameAvg["stones"][p][s][max([0, i-1])] for i, x in enumerate(gameAvg["stones"][p][s])])
        td = sum([(x < gameAvg["stones"][p][s][max([0, i-1])])*(x - gameAvg["stones"][p][s][max([0, i-1])]) for i, x in enumerate(gameAvg["stones"][p][s])])
        throwCount[p_i] += tc
        throwDistance[p_i] += td


print("Anzahl geworfen worden:\nSpieler 0: {}\nSpieler 1: {}\n\nverlorene Distanz: \nSpieler 0: {}\nSpieler 1: {}".format(*throwCount, *throwDistance))
# Out:
# Anzahl geworfen worden:
# Spieler 0: 10
# Spieler 1: 2
#
# verlorene Distanz:
# Spieler 0: -75
# Spieler 1: -15

# %%
throwCount = [0, 0]
throwDistance = [0, 0]
history = getHistoryFromDB(db_dir, db_filename)
print("History geladen")
# Out:
# History geladen

# %%
throwCount = [0, 0]
throwDistance = [0, 0]
anfield = [0, 0]
afield = [0, 0]
drfield = [0, 0]
for game in history[:100000]:
    for p_i, p in enumerate(game["stones"]):
        for s in game["stones"][p]:
            tc = sum([x < game["stones"][p][s][max([0, i-1])] for i, x in enumerate(game["stones"][p][s])])
            td = sum([(x < game["stones"][p][s][max([0, i-1])])*(x - game["stones"][p][s][max([0, i-1])]) for i, x in enumerate(game["stones"][p][s])])
            af = sum([x == 8 for x in game["stones"][p][s]])
            afn = sum([(x != game["stones"][p][s][max([0, i-1])])*(x == 8) for i, x in enumerate(game["stones"][p][s])])
            dr = sum([(x != game["stones"][p][s][max([0, i-1])])*(x in [4, 8, 14]) for i, x in enumerate(game["stones"][p][s])])
            throwCount[p_i] += tc
            throwDistance[p_i] += td
            anfield[p_i] += afn
            afield[p_i] += af
            drfield[p_i] += dr
# Out:
# Anzahl geworfen worden:
# Spieler 0: 7.46245
# Spieler 1: 2.55217
#
# verlorene Distanz:
# Spieler 0: -57.4512
# Spieler 1: -18.62202
#
#  Stein liegt auf 8:
# Spieler 0: 23.84912
# Spieler 1: 4.48969
#
#  8 getroffen:
# Spieler 0: 3.87505
# Spieler 1: 3.59972
#
#  Doubleroll getroffen:
# Spieler 0: 11.38675
# Spieler 1: 11.38065

# %%
# print("Anzahl geworfen worden:\nSpieler 0: {:3.2f}\nSpieler 1: {:3.2f}\n\nverlorene Distanz: \nSpieler 0: {:3.2f}\nSpieler 1: {:3.2f}\n\n Stein liegt auf 8: \nSpieler 0: {:3.2f}\nSpieler 1: {:3.2f}\n\n 8 getroffen: \nSpieler 0: {:3.2f}\nSpieler 1: {:3.2f}\n\n Doubleroll getroffen: \nSpieler 0: {:3.2f}\nSpieler 1: {:3.2f}".format(
#     *[x/len(history[:100000]) for x in throwCount], *[x/len(history[:100000]) for x in throwDistance], *[x/len(history[:100000]) for x in afield], *[x/len(history[:100000]) for x in anfield], *[x/len(history[:100000]) for x in drfield]))
# print("Anzahl geworfen worden:&{:3.2f}&{:3.2f}\\\\verlorene Distanz: &{:3.2f}&{:3.2f}\\\\ Stein liegt auf 8: &{:3.2f}&{:3.2f}\\\\ 8 getroffen: &{:3.2f}&{:3.2f}\\\\ Doubleroll getroffen: &{:3.2f}&{:3.2f}".format(
#     *[x/len(history[:100000]) for x in throwCount], *[x/len(history[:100000]) for x in throwDistance], *[x/len(history[:100000]) for x in afield], *[x/len(history[:100000]) for x in anfield], *[x/len(history[:100000]) for x in drfield]))
print("& {: 3.4f} & {: 3.4f}\\\\\n & {: 3.4f} & {: 3.4f}\\\\\n & {: 3.4f} & {: 3.4f}\\\\\n & {: 3.4f} & {: 3.4f}\\\\\n & {: 3.4f} & {: 3.4f}".format(
    *[x/(len(history[:100000])*roundInfo["⌀"]) for x in throwCount], *[x/(len(history[:100000])*roundInfo["⌀"]) for x in throwDistance], *[x/(len(history[:100000])*roundInfo["⌀"]) for x in afield], *[x/(len(history[:100000])*roundInfo["⌀"]) for x in anfield], *[x/(len(history[:100000])*roundInfo["⌀"]) for x in drfield]))
# Out:
# Anzahl geworfen worden:
# Spieler 0: 7.46
# Spieler 1: 2.55
#
# verlorene Distanz:
# Spieler 0: -57.45
# Spieler 1: -18.62
#
#  Stein liegt auf 8:
# Spieler 0: 23.85
# Spieler 1: 4.49
#
#  8 getroffen:
# Spieler 0: 3.88
# Spieler 1: 3.60
#
#  Doubleroll getroffen:
# Spieler 0: 11.39
# Spieler 1: 11.38
# Anzahl geworfen worden:&7.46&2.55\\verlorene Distanz: &-57.45&-18.62\\ Stein liegt auf 8: &23.85&4.49\\ 8 getroffen: &3.88&3.60\\ Doubleroll getroffen: &11.39&11.38
# &  0.1416 &  0.0484\\
#  & -1.0902 & -0.3534\\
#  &  0.4526 &  0.0852\\
#  &  0.0735 &  0.0683\\
#  &  0.2161 &  0.2160

# %% [markdown]
# ## Das kürzeste Spiel in der Simulation

# %%
gameIDSpecial = rc.index(int(np.round(roundInfo["max"])))

print("ID für Spiel:", ids[0][gameIDSpecial])
gameSpecial = getGameFromDB(ids[0][gameIDSpecial], db_dir, db_filename)
print("Daten geladen")
figMovementFastest = drawGame(gameSpecial, gameSettings[0],figsize =[18,9])
# Out:
# ID für Spiel: 613156
# Daten geladen

# %% [markdown]
# ## Wer gewinnt?

# %%
def wer_gewinnt(winners, figsize=[15, 5]):

    player0 = [s.count(["p0"]) / len(s) * 100 for s in winners]
    player1 = [s.count(["p1"]) / len(s) * 100 for s in winners]
    no_one = [s.count([]) / len(s) * 100 for s in winners]
    # both = [s.count(["p0", "p1"]) / len(s) * 100 for s in winners]
    # print(player0)
    # print(player1)

    fig, ax = plt.subplots(figsize=figsize, layout="constrained")
    # hat_graph(ax, xlabels, [player0, player1], ['Player 0', 'Player 1'])

    p0 = ax.bar(
        labels,
        player0,
        label="Spieler 0",
        alpha=0.5,
        width=0.5,
        color=colors[0],
        hatch="///",
        edgecolor="dimgray",
    )
    p1 = ax.bar(
        labels,
        player1,
        label="Spieler 1",
        alpha=0.5,
        width=0.5,
        bottom=player0,
        color=colors,
        hatch="\\\\\\",
        edgecolor="dimgray",
    )
    ab = ax.bar(labels, no_one, label="Abbruch", alpha=.5, width=.5, color=colors,
                hatch="...", bottom=[sum(x) for x in zip(player0, player1)])
    # ev = ax.bar(labels, both, label="Unentschieden", alpha=.5, width=.5, color=colors,
    #             hatch="***", bottom=[sum(x) for x in zip(player0, player1, no_one)])

    ax.bar_label(p0, label_type="center", fmt="%3.5g%%", padding=5)
    ax.bar_label(p1, label_type="center", fmt="%3.5g%%", padding=5)
    ax.bar_label(ab, label_type='center', fmt=" "*30+"%3.5g%%", padding=5)
    # ax.bar_label(ev, label_type='center', fmt="%3.5g%%"+" "*30, padding=5)


    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_xlabel("Strategiepaarung (Strategie Spieler 0 vs Strategie Spieler 1)")
    ax.set_title("Wer gewinnt")
    # ax.legend( loc='lower center', ncol=2)
    ax.legend()
    ax.axhline(50, color=(0, 0, 0, 0.3), ls="--")

    fig.tight_layout()
    ax.set_yticks(np.linspace(0, 100, 11))

    ax.set_ylim(0,110)
    ax.yaxis.set_major_formatter(mt.PercentFormatter())
    ax.grid(axis="y", color=("gray"), alpha=0.3, ls="--")
    plt.show()

wer_gewinnt(winners,[5, 5])
# Out:
# C:\Users\walli\AppData\Local\Temp/ipykernel_1032/1652222094.py:52: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   fig.tight_layout()

# %% [markdown]
# ## Speichern der Grafiken

# %%
figRounds7s.savefig("../../tex/game_ur_ba_thesis/img/Grafiken/Strategien/"+graphic_dir+"/rounds.png", dpi=300,)
figMovement.savefig( "../../tex/game_ur_ba_thesis/img/Grafiken/Strategien/"+graphic_dir+"/Spielverlauf.png", dpi=300,)
